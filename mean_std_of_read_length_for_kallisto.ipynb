# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("./read_lengths.txt", sep=" ", names=["length", "count"])
data
# Out:
#     length      count
# 0       36     677463
# 1       37     866495
# 2       38     950448
# 3       39     975366
# 4       40     986895
# 5       41     994508
# 6       42    1036917
# 7       43    1041480
# 8       44    1092769
# 9       45    1141127
# 10      46    1194023
# 11      47    1220066
# 12      48    1256352
# 13      49    1287053
# 14      50    1287924
# 15      51    1313116
# 16      52    1274845
# 17      53    1291375
# 18      54    1310253
# 19      55    1331525
# 20      56    1392829
# 21      57    1414027
# 22      58    1439540
# 23      59    1479404
# 24      60    1491109
# 25      61    1484024
# 26      62    1456542
# 27      63    1469693
# 28      64    1476797
# 29      65    1513321
# 30      66    1477135
# 31      67    1523445
# 32      68    1538263
# 33      69    1759122
# 34      70    2076227
# 35      71    4023638
# 36      72   13872011
# 37      73   34534017
# 38      74  123881348
# 39      75  303724677

# %%
#Average length.
sum(data["length"]*data["count"]) / sum(data["count"])
# Out:
# 72.78445053234542

# %%
#Standard deviation.
(np.repeat(data["length"], data["count"])).std()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_126678/588903034.py in <module>
#       1 #Standard deviation.
# ----> 2 (np.repeat(data["length"], data["count"])).std()
#
# <__array_function__ internals> in repeat(*args, **kwargs)
#
# ~/anaconda3/envs/EMUscRNA/lib/python3.9/site-packages/numpy/core/fromnumeric.py in repeat(a, repeats, axis)
#     477
#     478     """
# --> 479     return _wrapfunc(a, 'repeat', repeats, axis=axis)
#     480
#     481
#
# ~/anaconda3/envs/EMUscRNA/lib/python3.9/site-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      55
#      56     try:
# ---> 57         return bound(*args, **kwds)
#      58     except TypeError:
#      59         # A TypeError occurs if the object does have such a method in its
#
# ...

# %%
sum(data["length"]*data["count"])
# Out:
# 38252389769

# %%
sum(data["l"]*data["n"]) / sum(data["n"])
